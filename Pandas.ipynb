# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("hw_25000.csv")

# %%
df
# Out:
#        Index   "Height(Inches)"   "Weight(Pounds)"
# 0          1           65.78331           112.9925
# 1          2           71.51521           136.4873
# 2          3           69.39874           153.0269
# 3          4           68.21660           142.3354
# 4          5           67.78781           144.2971
# ...      ...                ...                ...
# 24995  24996           69.50215           118.0312
# 24996  24997           64.54826           120.1932
# 24997  24998           64.69855           118.2655
# 24998  24999           67.52918           132.2682
# 24999  25000           68.87761           124.8742
#
# [25000 rows x 3 columns]

# %%
df.dtypes
# Out:
# Index                  int64
#  "Height(Inches)"    float64
#  "Weight(Pounds)"    float64
# dtype: object

# %%
df.head(5)
# Out:
#    Index   "Height(Inches)"   "Weight(Pounds)"
# 0      1           65.78331           112.9925
# 1      2           71.51521           136.4873
# 2      3           69.39874           153.0269
# 3      4           68.21660           142.3354
# 4      5           67.78781           144.2971

# %%
df.columns
# Out:
# Index(['Index', ' "Height(Inches)"', ' "Weight(Pounds)"'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[1.000000e+00, 6.578331e+01, 1.129925e+02],
#        [2.000000e+00, 7.151521e+01, 1.364873e+02],
#        [3.000000e+00, 6.939874e+01, 1.530269e+02],
#        ...,
#        [2.499800e+04, 6.469855e+01, 1.182655e+02],
#        [2.499900e+04, 6.752918e+01, 1.322682e+02],
#        [2.500000e+04, 6.887761e+01, 1.248742e+02]])

# %%
df.describe()
# Out:
#               Index   "Height(Inches)"   "Weight(Pounds)"
# count  25000.000000       25000.000000       25000.000000
# mean   12500.500000          67.993114         127.079421
# std     7217.022701           1.901679          11.660898
# min        1.000000          60.278360          78.014760
# 25%     6250.750000          66.704397         119.308675
# 50%    12500.500000          67.995700         127.157750
# 75%    18750.250000          69.272958         134.892850
# max    25000.000000          75.152800         170.924000

# %%
df.T
# Out:
#                        0          1          2         3          4      \
# Index                1.00000    2.00000    3.00000    4.0000    5.00000
#  "Height(Inches)"   65.78331   71.51521   69.39874   68.2166   67.78781
#  "Weight(Pounds)"  112.99250  136.48730  153.02690  142.3354  144.29710
#
#                        5          6          7          8          9      ...  \
# Index                6.00000    7.00000    8.00000    9.00000   10.00000  ...
#  "Height(Inches)"   68.69784   69.80204   70.01472   67.90265   66.78236  ...
#  "Weight(Pounds)"  123.30240  141.49470  136.46230  112.37230  120.66720  ...
#
#                          24990        24991        24992        24993  \
# Index              24991.00000  24992.00000  24993.00000  24994.00000
#  "Height(Inches)"     69.97767     71.91656     70.96218     66.19462
#  "Weight(Pounds)"    125.36720    128.28400    146.19360    118.79740
#
#                          24994        24995        24996        24997  \
# ...

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#        Index   "Weight(Pounds)"   "Height(Inches)"
# 0          1           112.9925           65.78331
# 1          2           136.4873           71.51521
# 2          3           153.0269           69.39874
# 3          4           142.3354           68.21660
# 4          5           144.2971           67.78781
# ...      ...                ...                ...
# 24995  24996           118.0312           69.50215
# 24996  24997           120.1932           64.54826
# 24997  24998           118.2655           64.69855
# 24998  24999           132.2682           67.52918
# 24999  25000           124.8742           68.87761
#
# [25000 rows x 3 columns]

# %%
df[1:3]
# Out:
#    Index   "Height(Inches)"   "Weight(Pounds)"
# 1      2           71.51521           136.4873
# 2      3           69.39874           153.0269

# %%
df.loc[:,[' "Height(Inches)"', ' "Weight(Pounds)"']]
# Out:
#         "Height(Inches)"   "Weight(Pounds)"
# 0               65.78331           112.9925
# 1               71.51521           136.4873
# 2               69.39874           153.0269
# 3               68.21660           142.3354
# 4               67.78781           144.2971
# ...                  ...                ...
# 24995           69.50215           118.0312
# 24996           64.54826           120.1932
# 24997           64.69855           118.2655
# 24998           67.52918           132.2682
# 24999           68.87761           124.8742
#
# [25000 rows x 2 columns]

# %%
df=df.loc[:,[' "Height(Inches)"', ' "Weight(Pounds)"']]

# %%
df
# Out:
#         "Height(Inches)"   "Weight(Pounds)"
# 0               65.78331           112.9925
# 1               71.51521           136.4873
# 2               69.39874           153.0269
# 3               68.21660           142.3354
# 4               67.78781           144.2971
# ...                  ...                ...
# 24995           69.50215           118.0312
# 24996           64.54826           120.1932
# 24997           64.69855           118.2655
# 24998           67.52918           132.2682
# 24999           68.87761           124.8742
#
# [25000 rows x 2 columns]

# %%
df.iloc[3]
# Out:
#  "Height(Inches)"     68.2166
#  "Weight(Pounds)"    142.3354
# Name: 3, dtype: float64

# %%
df.iloc[1:3,:]
# Out:
#     "Height(Inches)"   "Weight(Pounds)"
# 1           71.51521           136.4873
# 2           69.39874           153.0269

# %%
df.iloc[[1,2,5],:]
# Out:
#     "Height(Inches)"   "Weight(Pounds)"
# 1           71.51521           136.4873
# 2           69.39874           153.0269
# 5           68.69784           123.3024

# %%
df.iat[2,1]
# Out:
# 153.0269

# %%
df[df[' "Height(Inches)"'] > 70]
# Out:
#         "Height(Inches)"   "Weight(Pounds)"
# 1               71.51521           136.4873
# 7               70.01472           136.4623
# 15              71.09160           139.9975
# 18              71.23033           137.9025
# 26              70.84235           142.4235
# ...                  ...                ...
# 24973           71.32072           125.5928
# 24976           70.06322           115.4180
# 24989           70.11839           141.2370
# 24991           71.91656           128.2840
# 24992           70.96218           146.1936
#
# [3666 rows x 2 columns]

# %%
a=np.array([2])
b=a
a[0]=5

# %%
b
# Out:
# array([5])

# %%
a=np.array([2])
b=a.copy()
a[0]=5

# %%
b
# Out:
# array([2])

# %%
df
# Out:
#         "Height(Inches)"   "Weight(Pounds)"
# 0               65.78331           112.9925
# 1               71.51521           136.4873
# 2               69.39874           153.0269
# 3               68.21660           142.3354
# 4               67.78781           144.2971
# ...                  ...                ...
# 24995           69.50215           118.0312
# 24996           64.54826           120.1932
# 24997           64.69855           118.2655
# 24998           67.52918           132.2682
# 24999           68.87761           124.8742
#
# [25000 rows x 2 columns]

# %%
df['Height']=df[' "Height(Inches)"']*2.54
df['Weight']=df[' "Weight(Pounds)"']*0.4535924

# %%
df
# Out:
#         "Height(Inches)"   "Weight(Pounds)"      Height     Weight
# 0               65.78331           112.9925  167.089607  51.252539
# 1               71.51521           136.4873  181.648633  61.909602
# 2               69.39874           153.0269  176.272800  69.411839
# 3               68.21660           142.3354  173.270164  64.562256
# 4               67.78781           144.2971  172.181037  65.452068
# ...                  ...                ...         ...        ...
# 24995           69.50215           118.0312  176.535461  53.538055
# 24996           64.54826           120.1932  163.952580  54.518722
# 24997           64.69855           118.2655  164.334317  53.644332
# 24998           67.52918           132.2682  171.524117  59.995850
# 24999           68.87761           124.8742  174.949129  56.641988
#
# [25000 rows x 4 columns]

# %%
df=df.iloc[:,2:]
df
# Out:
#            Height     Weight
# 0      167.089607  51.252539
# 1      181.648633  61.909602
# 2      176.272800  69.411839
# 3      173.270164  64.562256
# 4      172.181037  65.452068
# ...           ...        ...
# 24995  176.535461  53.538055
# 24996  163.952580  54.518722
# 24997  164.334317  53.644332
# 24998  171.524117  59.995850
# 24999  174.949129  56.641988
#
# [25000 rows x 2 columns]

# %%
df["label"]=[("one" if i>180 else "two") for i in df.Height]

# %%
df
# Out:
#            Height     Weight label
# 0      167.089607  51.252539   two
# 1      181.648633  61.909602   one
# 2      176.272800  69.411839   two
# 3      173.270164  64.562256   two
# 4      172.181037  65.452068   two
# ...           ...        ...   ...
# 24995  176.535461  53.538055   two
# 24996  163.952580  54.518722   two
# 24997  164.334317  53.644332   two
# 24998  171.524117  59.995850   two
# 24999  174.949129  56.641988   two
#
# [25000 rows x 3 columns]

# %% [markdown]
# Výběr řádků podle kateorií, které chcee, např. jestli je hodnota "label"

# %%
df[df["label"].isin(["one"])]
# Out:
#            Height     Weight label
# 1      181.648633  61.909602   one
# 15     180.572664  63.501802   one
# 18     180.925038  62.551526   one
# 34     182.384294  63.548976   one
# 92     181.578301  63.779809   one
# ...           ...        ...   ...
# 24926  182.104919  70.071453   one
# 24939  183.791581  65.296758   one
# 24973  181.154629  56.967940   one
# 24991  182.668062  58.188647   one
# 24992  180.243937  66.312306   one
#
# [1646 rows x 3 columns]

# %%
df["test"]=df["Height"].apply(lambda x: 1 if x>180 else 0)

# %%
df
# Out:
#            Height     Weight label  test
# 0      167.089607  51.252539   two     0
# 1      181.648633  61.909602   one     1
# 2      176.272800  69.411839   two     0
# 3      173.270164  64.562256   two     0
# 4      172.181037  65.452068   two     0
# ...           ...        ...   ...   ...
# 24995  176.535461  53.538055   two     0
# 24996  163.952580  54.518722   two     0
# 24997  164.334317  53.644332   two     0
# 24998  171.524117  59.995850   two     0
# 24999  174.949129  56.641988   two     0
#
# [25000 rows x 4 columns]

# %%
df.iloc[:,:2].apply(lambda x: x.max() - x.min())
# Out:
# Height    37.781078
# Weight    42.142925
# dtype: float64

# %%
df.Height.value_counts()
# Out:
# 172.569149    3
# 166.771218    3
# 172.682129    3
# 175.093782    3
# 175.066452    3
#              ..
# 163.981765    1
# 174.165387    1
# 173.014615    1
# 171.890385    1
# 166.059587    1
# Name: Height, Length: 24503, dtype: int64

# %%
df.rename(columns={
    'test': 'Test'
    }, inplace=True)

# %%
df[100:]
# Out:
#            Height     Weight label  Test
# 100    164.780824  46.308473   two     0
# 101    170.415509  59.127130   two     0
# 102    173.602929  60.864933   two     0
# 103    166.651254  44.742958   two     0
# 104    172.098995  51.963500   two     0
# ...           ...        ...   ...   ...
# 24995  176.535461  53.538055   two     0
# 24996  163.952580  54.518722   two     0
# 24997  164.334317  53.644332   two     0
# 24998  171.524117  59.995850   two     0
# 24999  174.949129  56.641988   two     0
#
# [24900 rows x 4 columns]

# %%
pd.concat([df[:10],df[20:]])
# Out:
#            Height     Weight label  test
# 0      167.089607  51.252539   two     0
# 1      181.648633  61.909602   one     1
# 2      176.272800  69.411839   two     0
# 3      173.270164  64.562256   two     0
# 4      172.181037  65.452068   two     0
# ...           ...        ...   ...   ...
# 24995  176.535461  53.538055   two     0
# 24996  163.952580  54.518722   two     0
# 24997  164.334317  53.644332   two     0
# 24998  171.524117  59.995850   two     0
# 24999  174.949129  56.641988   two     0
#
# [24990 rows x 4 columns]

# %%
df1 = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar','foo', 'bar', 'foo', 'foo'],
                    'B': ['one', 'one', 'two', 'three','two', 'two', 'one', 'three'],
                    'C': np.random.randn(8),
                    'D': np.random.randn(8)})
df1
# Out:
#      A      B         C         D
# 0  foo    one -0.102506 -1.670066
# 1  bar    one  2.016596 -2.459133
# 2  foo    two  0.650306  2.170666
# 3  bar  three  1.158063  1.242378
# 4  foo    two  0.295559  0.865116
# 5  bar    two  0.869255 -0.662080
# 6  foo    one -1.589645  0.071325
# 7  foo  three  0.261151 -1.368328

# %%
df1.groupby("A").sum()
# Out:
#             C         D
# A
# bar  4.043915 -1.878835
# foo -0.485136  0.068713

# %%
df1.groupby(["A","B"]).sum()
# Out:
#                   C         D
# A   B
# bar one    2.016596 -2.459133
#     three  1.158063  1.242378
#     two    0.869255 -0.662080
# foo one   -1.692152 -1.598741
#     three  0.261151 -1.368328
#     two    0.945864  3.035782

# %%
df1.groupby(["A","B"]).count()
# Out:
#            C  D
# A   B
# bar one    1  1
#     three  1  1
#     two    1  1
# foo one    2  2
#     three  1  1
#     two    2  2

# %%
df1.groupby("A").size()
# Out:
# A
# bar    3
# foo    5
# dtype: int64

# %%
df1.loc[:,["A","C"]].groupby("A").sum()
# Out:
#             C
# A
# bar  4.043915
# foo -0.485136

# %%
df1.sort_values(by="D")
# Out:
#      A      B         C         D
# 1  bar    one  2.016596 -2.459133
# 0  foo    one -0.102506 -1.670066
# 7  foo  three  0.261151 -1.368328
# 5  bar    two  0.869255 -0.662080
# 6  foo    one -1.589645  0.071325
# 4  foo    two  0.295559  0.865116
# 3  bar  three  1.158063  1.242378
# 2  foo    two  0.650306  2.170666

# %%
import matplotlib.pyplot as plt
plt.close('all')

# %%
df1.plot()
# Out:
# <AxesSubplot:>

# %%
df1.sort_values(by="D").plot()
# Out:
# <AxesSubplot:>

# %%
df1.sort_values(by="D").reset_index(drop=True).plot()
# Out:
# <AxesSubplot:>

# %%
df2=pd.read_csv('/home/martin/AE stream/c.csv')
df2
# Out:
#             Amp
# 0     -0.003816
# 1     -0.001397
# 2      0.000973
# 3      0.003168
# 4      0.004615
# ...         ...
# 99995 -0.001172
# 99996 -0.000461
# 99997 -0.003629
# 99998 -0.003866
# 99999 -0.003280
#
# [100000 rows x 1 columns]

# %%
df2[:100].plot(figsize=(16,5))
# Out:
# <AxesSubplot:>

# %%
# Out:
# <AxesSubplot:>
